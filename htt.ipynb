# %%
! git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.email "deffy2006@gmail.com"
# !git config --global user.name "aholicg"

# %%
# !git clone https://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@github.com/AIAdvWeather/Weather
# Out:
# Cloning into 'Weather'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 57 (delta 22), reused 18 (delta 7), pack-reused 0
# Receiving objects: 100% (57/57), 3.11 MiB | 9.59 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# !git pull origin main
# Out:
# From https://github.com/AIAdvWeather/Weather
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git checkout Hoang-Trang
# Out:
# Already on 'Hoang-Trang'
# Your branch is up to date with 'origin/Hoang-Trang'.

# %%
# !cp /content/drive/MyDrive/AI\ Adventures/Project/htt.ipynb /content/Weather/

# %%
# %cd Weather
# Out:
# /content/Weather

# %%
# !git add htt.ipynb

# %%
# !git commit -m "git - HTT"
# Out:
# [Hoang-Trang 94f8210] git - HTT
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite htt.ipynb (86%)

# %%
# !git push origin Hoang-Trang
# Out:
# Everything up-to-date
