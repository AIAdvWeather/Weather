# %%
! git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.email "deffy2006@gmail.com"
# !git config --global user.name "aholicg"

# %%
# !git clone https://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@github.com/AIAdvWeather/Weather
# Out:
# Cloning into 'Weather'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 26 (delta 8), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (26/26), 2.96 MiB | 7.24 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (1/1), 927 bytes | 927.00 KiB/s, done.
# From https://github.com/AIAdvWeather/Weather
#  * branch            main       -> FETCH_HEAD
#    094b3ec..a403001  main       -> origin/main
# Updating ef4e856..a403001
# Fast-forward

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git checkout Hoang-Trang
# Out:
# Already on 'Hoang-Trang'
# Your branch is ahead of 'origin/Hoang-Trang' by 1 commit.
#   (use "git push" to publish your local commits)

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/htt.ipynb /content/Weather/

# %%
# %cd Weather
# Out:
# /content/Weather

# %%
# !git add weather.ipynb

# %%
# !git commit -m "HTT added pairplot (pre <string to float>)"
# Out:
# On branch Hoang-Trang
# Your branch is up to date with 'origin/Hoang-Trang'.
#
# nothing to commit, working tree clean

# %%
# !git push origin Hoang-Trang
# Out:
# Everything up-to-date
